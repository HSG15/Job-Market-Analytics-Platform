# %%
import requests
from datetime import datetime

today = datetime.now().strftime("%Y-%m-%d")

payload = {
    "job_titles": ["Data Engineer", "Data Analyst", "Data Scientist"],
    "keywords": [
        "Python", "PySpark", "Apache Spark", "Java", "Scala",
        "SQL", "Databricks", "Kafka", "Airflow", "Azure",
        "AWS", "GCP", "ETL", "Hadoop", "Git", "GitHub",
        "Snowflake", "Docker", "Kubernetes", "Data Modeling", "Gen AI"
    ],
    "geo_locations": [{
        "city": "",
        "region": "",
        "country": "India"
    }],
    "date_posted_after": today,
    "limit": 10
}

response = requests.post(
    "https://api.hirebase.org/v2/jobs/search",
    json=payload
)

data = response.json()
print(data)
# Out:
# {'jobs': [{'_id': '690b39ca7f3f13281a9af9ef', 'company_name': 'Precision AQ', 'job_title': 'Senior Data Analyst', 'application_link': 'https://job-boards.greenhouse.io/precisionaq/jobs/5674949004', 'location_raw': 'Remote, India', 'job_type': 'Full Time', 'location_type': 'Remote', 'date_posted': '2025-10-09', 'company_link': 'www.precisionaq.com', 'company_logo': 'https://media.licdn.com/dms/image/v2/D560BAQFw1PIwMuhL7g/company-logo_200_200/company-logo_200_200/0/1727284706061/precision_aq_logo?e=2147483647&v=beta&t=a1SIt61EjV8JDON42IkAVGTjOG4pHvlNRBO1eueqEkg', 'job_board': 'greenhouse', 'job_board_link': 'https://boards.greenhouse.io/precisionaq', 'company_slug': 'precision-aq', 'language': 'en', 'description': '<p>The Senior Data Analyst – Market Research will support multiple market research projects in the Evidence Solutions Team. The job responsibilities include understanding the ever-changing and complex healthcare market and helping clients solve issues including distribution
# ...
